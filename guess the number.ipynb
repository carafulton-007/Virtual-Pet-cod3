# %%
import random
import time

print("Lets play guess the number.")
time.sleep(0.5)
print("A random number will be chosen between 1 and 100. You have to guess the number!")


number = random.randint(1, 100)
tries = 0

time.sleep(2)



while True: 
    guess = input("Guess a number between 1 and 100: ")
    if not guess.isdigit(): 
        print("Please enter a valid number.")
        continue
    guess = int(guess)
    tries += 1
   
    if guess < number:
        print(f"{guess} Is Too Low! Try Again.")
    elif guess > number:
        print(f"{guess} Is Too High! Try Again.")
    elif guess > 100 or guess < 1:
        print("Number must be between 1 and 100. Try again.")
    else:
        print(f"Congratulations! You guessed it in {tries} tries. Try beat your score next time!")
        break
# Out:
# Lets play guess the number.
# A random number will be chosen between 1 and 100. You have to guess the number!
# Guess a number between 1 and 100:  67
# Too low! Try again.
# Guess a number between 1 and 100:  78
# Too low! Try again.
# Guess a number between 1 and 100:  98
# Too high! Try again.
# Guess a number between 1 and 100:  86
# Too high! Try again.
# Guess a number between 1 and 100:  83
# Too low! Try again.
# Guess a number between 1 and 100:  85
# Too high! Try again.
# Guess a number between 1 and 100:  84
# Congratulations! You guessed it in 7 tries. Try beat your score next time!

# %%
import random
import time

print("Lets play guess the number.")
time.sleep(0.5)
print("A random number will be chosen between 1 and 100. You have to guess the number!")


number = random.randint(1, 100)
tries = 0

time.sleep(2)


def guess_number():
    while True: 
       guess = input("Guess a number between 1 and 100: ")
       if not guess.isdigit(): 
       print("Please enter a valid number.")
       continue
       guess = int(guess)
       tries += 1
   
        if guess < number:
           print("Too low! Try again.")
        elif guess > number:
           print("Too high! Try again.")
       elif guess > 100 or guess < 1:
           print("Number must be between 1 and 100. Try again.")
       else:
           print(f"Congratulations! You guessed it in {tries} tries. Try beat your score next time!")
       break

guess_number()
